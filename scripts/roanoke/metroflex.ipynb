# %%
import pathlib

import pandas as pd

from transit import cleaning

# %%
project_root = pathlib.Path('../..')
project_root.resolve()
# Out:
# PosixPath('/home/jnban/projects/roanoke-transit')

# %%
path_output = project_root / 'web/va/roanoke/metroflex'
path_output.mkdir(exist_ok=True, parents=True)
path_output.resolve()
# Out:
# PosixPath('/home/jnban/projects/roanoke-transit/web/va/roanoke/metroflex')

# %%
src_df = pd.read_excel(
    project_root / 'data/metroflex/Copy of FEBRUARY 2025 METRO FLX TRIP REPORT.xls',
    sheet_name='Sheet1',
    header=2
)
src_df
# Out:
#                  Customer Customer Summary          Trip Date Pickup Address  \
# 0                     NaN              NaN                NaN            NaN
# 1     2025-02-04 22:54:16              NaN                NaN            NaN
# 2                 No show              Yes  ROSS/ CITI TRENDS          apts.
# 3                     NaN              NaN                  0            NaN
# 4                     NaN              NaN                NaN            NaN
# ...                   ...              ...                ...            ...
# 3896              No show               No     CEI -- ROANOKE            NaN
# 3897  2025-02-14 23:00:44              NaN                NaN            NaN
# 3898              No show               No     CEI -- ROANOKE            NaN
# 3899                  NaN              NaN                  0            NaN
# 3900         Page -1 of 1              NaN                NaN            NaN
#
#      Dropoff Address  Miles                           Pickup Address.1  \
# 0                NaN    NaN                                        NaN
# 1                NaN    NaN                                        NaN
# 2             Guests    0.0  1415 Towne Square Blvd\nRoanoke, VA 24012
# 3                NaN    NaN                                        NaN
# 4                NaN    NaN                                        NaN
# ...              ...    ...                                        ...
# 3896          Guests    0.0   4411 Plantation Rd Ne\nRoanoke, VA 24019
# 3897             NaN    NaN                                        NaN
# 3898          Guests    0.0   4411 Plantation Rd Ne\nRoanoke, VA 24019
# 3899             NaN    NaN                                        NaN
# 3900             NaN    NaN                                        NaN
#
#                            Dropoff Address.1  Unnamed: 8  Unnamed: 9  \
# 0                                        NaN         NaN         NaN
# 1                                        NaN         NaN         NaN
# 2     1720  Grandin Rd Sw\nRoanoke, VA 24018         NaN         0.0
# 3                                        NaN         NaN         NaN
# 4                                        NaN         NaN         NaN
# ...                                      ...         ...         ...
# 3896      1321 Leon St Nw\nRoanoke, VA 24017         NaN         0.0
# 3897                                     NaN         NaN         NaN
# 3898      1321 Leon St Nw\nRoanoke, VA 24017         NaN         0.0
# 3899                                     NaN         NaN         NaN
# 3900                                     NaN         NaN         NaN
#
#       Unnamed: 10  Unnamed: 11 Unnamed: 12  Unnamed: 13  Unnamed: 14  \
# 0             NaN          NaN         NaN          NaN          NaN
# 1             NaN          NaN         NaN          NaN          NaN
# 2             NaN          NaN  Attendants          0.0          NaN
# 3             NaN          NaN         NaN          NaN          NaN
# 4             NaN          NaN         NaN          NaN          NaN
# ...           ...          ...         ...          ...          ...
# 3896          NaN          NaN  Attendants          0.0          NaN
# 3897          NaN          NaN         NaN          NaN          NaN
# 3898          NaN          NaN  Attendants          0.0          NaN
# 3899          NaN          NaN         NaN          NaN          NaN
# 3900          NaN          NaN         NaN          NaN          NaN
#
#       Unnamed: 15  Unnamed: 16  Unnamed: 17
# 0             NaN          NaN          NaN
# 1             NaN          NaN          NaN
# 2             NaN          NaN          NaN
# 3             NaN          NaN          NaN
# 4             NaN          NaN          NaN
# ...           ...          ...          ...
# 3896          NaN          NaN          NaN
# 3897          NaN          NaN          NaN
# 3898          NaN          NaN          NaN
# 3899          NaN          NaN          NaN
# 3900          NaN          NaN          NaN
#
# [3901 rows x 18 columns]

# %%
df = cleaning.drop_empty_rows(src_df)
df.drop(df.index[-1], inplace=True) # drop last row
df.rename(columns={'Trip Date': 'Pickup Address Details'}, inplace=True)

df = cleaning.downshift_alternating_values(df, column='Customer', target='Trip Date', increment=2)
df = cleaning.drop_empty_rows(df)

df.drop([
    'Customer',
    'Dropoff Address',
    'Unnamed: 8',
    'Unnamed: 9',
    'Unnamed: 10',
    'Unnamed: 11',
    'Unnamed: 12',
    'Unnamed: 14',
    'Unnamed: 15',
    'Unnamed: 16',
    'Unnamed: 17',
], axis=1, inplace=True)

df.rename(columns={
    'Customer Summary': 'No show',
    'Unnamed: 13': 'Attendants',
    'Pickup Address': 'Dropoff Address Details',
    'Pickup Address.1': 'Pickup Address',
    'Dropoff Address.1': 'Dropoff Address',
}, inplace=True)

df.to_csv(project_root / 'data/metroflex/metroflex-2025-02-trip-report-cleaned.csv')
df
# Out:
#      No show                             Pickup Address Details  \
# 2        Yes                                  ROSS/ CITI TRENDS
# 6         No  VA WESTERN/ MCFARLAND CENTER (RIGHT SIDE FROM ...
# 8         No  VA WESTERN/ MCFARLAND CENTER (RIGHT SIDE FROM ...
# 10        No  VA WESTERN/ MCFARLAND CENTER (RIGHT SIDE FROM ...
# 12        No  VA WESTERN/ MCFARLAND CENTER (RIGHT SIDE FROM ...
# ...      ...                                                ...
# 3890      No                                     CEI -- ROANOKE
# 3892      No                                     CEI -- ROANOKE
# 3894     Yes                                     CEI -- ROANOKE
# 3896      No                                     CEI -- ROANOKE
# 3898      No                                     CEI -- ROANOKE
#
#      Dropoff Address Details  Miles  \
# 2                      apts.    0.0
# 6                        NaN    0.0
# 8                        NaN    0.0
# 10                       NaN    0.0
# 12                       NaN    0.0
# ...                      ...    ...
# 3890                     NaN    0.0
# 3892                     NaN    0.0
# 3894                     NaN    0.0
# 3896                     NaN    0.0
# 3898                     NaN    0.0
#
#                                  Pickup Address  \
# 2     1415 Towne Square Blvd\nRoanoke, VA 24012
# 6       3094 Colonial Ave Sw\nRoanoke, VA 24015
# 8       3094 Colonial Ave Sw\nRoanoke, VA 24015
# 10      3094 Colonial Ave Sw\nRoanoke, VA 24015
# 12      3094 Colonial Ave Sw\nRoanoke, VA 24015
# ...                                         ...
# 3890   4411 Plantation Rd Ne\nRoanoke, VA 24019
# 3892   4411 Plantation Rd Ne\nRoanoke, VA 24019
# 3894   4411 Plantation Rd Ne\nRoanoke, VA 24019
# 3896   4411 Plantation Rd Ne\nRoanoke, VA 24019
# 3898   4411 Plantation Rd Ne\nRoanoke, VA 24019
#
#                              Dropoff Address  Attendants            Trip Date
# 2     1720  Grandin Rd Sw\nRoanoke, VA 24018         0.0  2025-02-04 22:54:16
# 6     1306 Carroll Ave Nw\nRoanoke, VA 24017         0.0  2025-01-28 21:21:17
# 8     1306 Carroll Ave Nw\nRoanoke, VA 24017         0.0  2025-02-03 22:05:34
# 10    1306 Carroll Ave Nw\nRoanoke, VA 24017         0.0  2025-02-04 21:38:53
# 12    1306 Carroll Ave Nw\nRoanoke, VA 24017         0.0  2025-02-17 22:42:00
# ...                                      ...         ...                  ...
# 3890      1321 Leon St Nw\nRoanoke, VA 24017         0.0  2025-01-31 22:49:07
# 3892      1321 Leon St Nw\nRoanoke, VA 24017         0.0  2025-02-05 22:59:48
# 3894      1321 Leon St Nw\nRoanoke, VA 24017         0.0  2025-02-12 23:00:00
# 3896      1321 Leon St Nw\nRoanoke, VA 24017         0.0  2025-02-13 23:12:26
# 3898      1321 Leon St Nw\nRoanoke, VA 24017         0.0  2025-02-14 23:00:44
#
# [1746 rows x 8 columns]
